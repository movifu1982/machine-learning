# %%
# data normalisation with sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
white_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', sep=";")

# %%
ohe = OneHotEncoder

# %%
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 4 else 'medium'
if value <= 6 else 'high')

# 3 4 5 are low, 6 7 medium, 8 and nonexistent 9 are high
#changed to: 3 4 low, 5 6 medium, 7 8 (and 9) high

white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality quality_label
# 0         8.8        6        medium
# 1         9.5        6        medium
# 2        10.1        6        medium
# 3         9.9        6        medium
# 4         9.9        6        medium
# ...       ...      ...           ...
# 4893     11.2        6        medium
# 4894      9.6        5        medium
# 4895      9.4        6        medium
# 4896     12.8        7          high
# 4897     11.8        6        medium
#
# [4898 rows x 13 columns]

# %%
#Skewness measures asymmetry in the data distribution

#print(white_wine['residual sugar'].astype(float).skew())

# %%
#Kurtosis identifies outliers: data with high kurtosis (heavy-tailed data) is proof of outliers, and data with low kurtosis (light-tailed data) lacks them.

#print(white_wine['residual sugar'].astype(float).kurt())

# %%
# x is all the features Im keeping
# y is target, quality , the new name.

#X.drop(['SalePrice'],axis=1,inplace=True) REMEMBER THE INPLACE!!

# %%
#white_wine["quality_label"].unique()
#white_wine ["quality_label"].value_counts()

# %%
#LOGISTIC REGRESSION

# %%
le = LabelEncoder()

# %%
new_wine = pd.DataFrame(white_wine, columns=['quality_label'])

new_wine['quality_label'] = new_wine['quality_label'].astype('category')

new_wine['quality_label_Cat'] = new_wine['quality_label'].cat.codes

new_wine
# Out:
#      quality_label  quality_label_Cat
# 0           medium                  1
# 1           medium                  1
# 2           medium                  1
# 3           medium                  1
# 4           medium                  1
# ...            ...                ...
# 4893        medium                  1
# 4894        medium                  1
# 4895        medium                  1
# 4896          high                  2
# 4897        medium                  1
#
# [4898 rows x 2 columns]

# %%
x_data = white_wine[["fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides", "free sulfur dioxide", "total sulfur dioxide", "density", "pH", "sulphates", "alcohol"]]
y_data = new_wine["quality_label_Cat"]

# %%
new_frame = [white_wine, new_wine]
new_frame
# Out:
# [      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
#  0               7.0              0.27         0.36            20.7      0.045
#  1               6.3              0.30         0.34             1.6      0.049
#  2               8.1              0.28         0.40             6.9      0.050
#  3               7.2              0.23         0.32             8.5      0.058
#  4               7.2              0.23         0.32             8.5      0.058
#  ...             ...               ...          ...             ...        ...
#  4893            6.2              0.21         0.29             1.6      0.039
#  4894            6.6              0.32         0.36             8.0      0.047
#  4895            6.5              0.24         0.19             1.2      0.041
#  4896            5.5              0.29         0.30             1.1      0.022
#  4897            6.0              0.21         0.38             0.8      0.020
#
#        free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
#  0                    45.0                 170.0  1.00100  3.00       0.45
#  1                    14.0                 132.0  0.99400  3.30       0.49
#  2                    30.0                  97.0  0.99510  3.26       0.44
#  3                    47.0                 186.0  0.99560  3.19       0.40
#  4                    47.0                 186.0  0.99560  3.19       0.40
#  ...                   ...                   ...      ...   ...        ...
#  4893                 24.0                  92.0  0.99114  3.27       0.50
#  4894                 57.0                 168.0  0.99490  3.15       0.46
#  4895                 30.0                 111.0  0.99254  2.99       0.46
#  4896                 20.0                 110.0  0.98869  3.34       0.38
#  4897                 22.0                  98.0  0.98941  3.26       0.32
#
#        alcohol  quality quality_label
#  0         8.8        6        medium
#  1         9.5        6        medium
#  2        10.1        6        medium
#  3         9.9        6        medium
#  4         9.9        6        medium
#  ...       ...      ...           ...
#  4893     11.2        6        medium
#  4894      9.6        5        medium
#  4895      9.4        6        medium
#  4896     12.8        7          high
#  4897     11.8        6        medium
#
#  [4898 rows x 13 columns],
#       quality_label  quality_label_Cat
#  0           medium                  1
#  1           medium                  1
#  2           medium                  1
#  3           medium                  1
#  4           medium                  1
#  ...            ...                ...
#  4893        medium                  1
#  4894        medium                  1
#  4895        medium                  1
#  4896          high                  2
#  4897        medium                  1
#
#  [4898 rows x 2 columns]]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data ,test_size = 0.3, shuffle=False)
x_train, x_test, y_train, y_test

#this is fine!
# Out:
# (      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
#  0               7.0              0.27         0.36           20.70      0.045
#  1               6.3              0.30         0.34            1.60      0.049
#  2               8.1              0.28         0.40            6.90      0.050
#  3               7.2              0.23         0.32            8.50      0.058
#  4               7.2              0.23         0.32            8.50      0.058
#  ...             ...               ...          ...             ...        ...
#  3423            7.1              0.18         0.39           14.50      0.051
#  3424            6.4              0.32         0.27            4.90      0.034
#  3425            7.1              0.17         0.40           14.55      0.047
#  3426            7.1              0.17         0.40           14.55      0.047
#  3427            5.8              0.24         0.26           10.05      0.039
#
#        free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
#  0                    45.0                 170.0  1.00100  3.00       0.45
#  1                    14.0                 132.0  0.99400  3.30       0.49
#  2                    30.0                  97.0  0.99510  3.26       0.44
#  3                    47.0                 186.0  0.99560  3.19       0.40
#  4                    47.0                 186.0  0.99560  3.19       0.40
#  ...                   ...                   ...      ...   ...        ...
#  3423                 48.0                 156.0  0.99947  3.35       0.78
#  3424                 18.0                 122.0  0.99160  3.36       0.71
#  3425                 47.0                 156.0  0.99945  3.34       0.78
#  3426                 47.0                 156.0  0.99945  3.34       0.78
#  3427                 63.0                 162.0  0.99375  3.33       0.50
#
#        alcohol
#  0         8.8
#  1         9.5
#  2        10.1
#  3         9.9
#  4         9.9
#  ...       ...
#  3423      9.1
#  3424     12.5
#  3425      9.1
#  3426      9.1
#  3427     11.2
#
#  [3428 rows x 11 columns],
#        fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
#  3428            6.4              0.32         0.27            4.90      0.034
#  3429            7.1              0.18         0.39           14.50      0.051
#  3430            7.1              0.17         0.40           14.55      0.047
#  3431            7.1              0.18         0.39           15.25      0.047
#  3432            7.8              0.29         0.29            3.15      0.044
#  ...             ...               ...          ...             ...        ...
#  4893            6.2              0.21         0.29            1.60      0.039
#  4894            6.6              0.32         0.36            8.00      0.047
#  4895            6.5              0.24         0.19            1.20      0.041
#  4896            5.5              0.29         0.30            1.10      0.022
#  4897            6.0              0.21         0.38            0.80      0.020
#
#        free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
#  3428                 18.0                 122.0  0.99160  3.36       0.71
#  3429                 48.0                 156.0  0.99947  3.35       0.78
#  3430                 47.0                 156.0  0.99945  3.34       0.78
#  3431                 45.0                 158.0  0.99946  3.34       0.77
#  3432                 41.0                 117.0  0.99153  3.24       0.35
#  ...                   ...                   ...      ...   ...        ...
#  4893                 24.0                  92.0  0.99114  3.27       0.50
#  4894                 57.0                 168.0  0.99490  3.15       0.46
#  4895                 30.0                 111.0  0.99254  2.99       0.46
#  4896                 20.0                 110.0  0.98869  3.34       0.38
#  4897                 22.0                  98.0  0.98941  3.26       0.32
#
#        alcohol
#  3428     12.5
#  3429      9.1
#  3430      9.1
#  3431      9.1
#  3432     11.5
#  ...       ...
#  4893     11.2
#  4894      9.6
#  4895      9.4
#  4896     12.8
#  4897     11.8
#
#  [1470 rows x 11 columns],
#  0       1
#  1       1
#  2       1
#  3       1
#  4       1
#         ..
#  3423    1
#  3424    1
#  3425    1
#  3426    1
#  3427    1
#  Name: quality_label_Cat, Length: 3428, dtype: int8,
#  3428    1
#  3429    1
#  3430    1
#  3431    1
#  3432    1
#         ..
#  4893    1
#  4894    1
#  4895    1
#  4896    2
#  4897    1
#  Name: quality_label_Cat, Length: 1470, dtype: int8)

# %%
# data normalisation with sklearn
from sklearn.preprocessing import MinMaxScaler

# fit scaler on training data
norm = MinMaxScaler().fit(x_train)

# transform training data
X_train_norm = norm.transform(x_train)

# transform testing data
X_test_norm = norm.transform(x_test)

# %%
len(x_test)
# Out:
# 1470

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# /Users/monicavillarfuentes/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred_lr = lr.predict(x_test)
pred_lr
# Out:
# array([1, 1, 1, ..., 1, 2, 2], dtype=int8)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

# %%
print("Accuracy score:", accuracy_score(y_test, pred_lr))
# Out:
# Accuracy score: 0.7442176870748299

# %%
from sklearn.metrics import cohen_kappa_score

# %%
kappa = cohen_kappa_score (pred_lr, y_test)
kappa
# Out:
# 0.30881229311701

# %%
print(classification_report(y_test, pred_lr, target_names=["low","medium","high"]))
# Out:
#               precision    recall  f1-score   support
#
#          low       0.00      0.00      0.00        39
#       medium       0.84      0.83      0.83      1127
#         high       0.45      0.53      0.48       304
#
#     accuracy                           0.74      1470
#    macro avg       0.43      0.45      0.44      1470
# weighted avg       0.74      0.74      0.74      1470
# /Users/monicavillarfuentes/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/monicavillarfuentes/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/monicavillarfuentes/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
white_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', sep=";")

# %%
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 4 else 'medium'
if value <= 6 else 'high')

# 3 4 5 are low, 6 7 medium, 8 and nonexistent 9 are high
#changed to: 3 4 low, 5 6 medium, 7 8 (and 9) high

white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality quality_label
# 0         8.8        6        medium
# 1         9.5        6        medium
# 2        10.1        6        medium
# 3         9.9        6        medium
# 4         9.9        6        medium
# ...       ...      ...           ...
# 4893     11.2        6        medium
# 4894      9.6        5        medium
# 4895      9.4        6        medium
# 4896     12.8        7          high
# 4897     11.8        6        medium
#
# [4898 rows x 13 columns]

# %%
x_data = white_wine[["fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides", "free sulfur dioxide", "total sulfur dioxide", "density", "pH", "sulphates", "alcohol"]]
y_data = new_wine["quality_label_Cat"]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data ,test_size = 0.3, shuffle=False)
x_train, x_test, y_train, y_test
# Out:
# (      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
#  0               7.0              0.27         0.36           20.70      0.045
#  1               6.3              0.30         0.34            1.60      0.049
#  2               8.1              0.28         0.40            6.90      0.050
#  3               7.2              0.23         0.32            8.50      0.058
#  4               7.2              0.23         0.32            8.50      0.058
#  ...             ...               ...          ...             ...        ...
#  3423            7.1              0.18         0.39           14.50      0.051
#  3424            6.4              0.32         0.27            4.90      0.034
#  3425            7.1              0.17         0.40           14.55      0.047
#  3426            7.1              0.17         0.40           14.55      0.047
#  3427            5.8              0.24         0.26           10.05      0.039
#
#        free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
#  0                    45.0                 170.0  1.00100  3.00       0.45
#  1                    14.0                 132.0  0.99400  3.30       0.49
#  2                    30.0                  97.0  0.99510  3.26       0.44
#  3                    47.0                 186.0  0.99560  3.19       0.40
#  4                    47.0                 186.0  0.99560  3.19       0.40
#  ...                   ...                   ...      ...   ...        ...
#  3423                 48.0                 156.0  0.99947  3.35       0.78
#  3424                 18.0                 122.0  0.99160  3.36       0.71
#  3425                 47.0                 156.0  0.99945  3.34       0.78
#  3426                 47.0                 156.0  0.99945  3.34       0.78
#  3427                 63.0                 162.0  0.99375  3.33       0.50
#
#        alcohol
#  0         8.8
#  1         9.5
#  2        10.1
#  3         9.9
#  4         9.9
#  ...       ...
#  3423      9.1
#  3424     12.5
#  3425      9.1
#  3426      9.1
#  3427     11.2
#
#  [3428 rows x 11 columns],
#        fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
#  3428            6.4              0.32         0.27            4.90      0.034
#  3429            7.1              0.18         0.39           14.50      0.051
#  3430            7.1              0.17         0.40           14.55      0.047
#  3431            7.1              0.18         0.39           15.25      0.047
#  3432            7.8              0.29         0.29            3.15      0.044
#  ...             ...               ...          ...             ...        ...
#  4893            6.2              0.21         0.29            1.60      0.039
#  4894            6.6              0.32         0.36            8.00      0.047
#  4895            6.5              0.24         0.19            1.20      0.041
#  4896            5.5              0.29         0.30            1.10      0.022
#  4897            6.0              0.21         0.38            0.80      0.020
#
#        free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
#  3428                 18.0                 122.0  0.99160  3.36       0.71
#  3429                 48.0                 156.0  0.99947  3.35       0.78
#  3430                 47.0                 156.0  0.99945  3.34       0.78
#  3431                 45.0                 158.0  0.99946  3.34       0.77
#  3432                 41.0                 117.0  0.99153  3.24       0.35
#  ...                   ...                   ...      ...   ...        ...
#  4893                 24.0                  92.0  0.99114  3.27       0.50
#  4894                 57.0                 168.0  0.99490  3.15       0.46
#  4895                 30.0                 111.0  0.99254  2.99       0.46
#  4896                 20.0                 110.0  0.98869  3.34       0.38
#  4897                 22.0                  98.0  0.98941  3.26       0.32
#
#        alcohol
#  3428     12.5
#  3429      9.1
#  3430      9.1
#  3431      9.1
#  3432     11.5
#  ...       ...
#  4893     11.2
#  4894      9.6
#  4895      9.4
#  4896     12.8
#  4897     11.8
#
#  [1470 rows x 11 columns],
#  0       1
#  1       1
#  2       1
#  3       1
#  4       1
#         ..
#  3423    1
#  3424    1
#  3425    1
#  3426    1
#  3427    1
#  Name: quality_label_Cat, Length: 3428, dtype: int8,
#  3428    1
#  3429    1
#  3430    1
#  3431    1
#  3432    1
#         ..
#  4893    1
#  4894    1
#  4895    1
#  4896    2
#  4897    1
#  Name: quality_label_Cat, Length: 1470, dtype: int8)

# %%
# data normalisation with sklearn
from sklearn.preprocessing import MinMaxScaler

# fit scaler on training data
norm = MinMaxScaler().fit(x_train)

# transform training data
X_train_norm = norm.transform(x_train)

# transform testing data
X_test_norm = norm.transform(x_test)

# %%
model.score (x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/monicavillarfuentes/codeacademy/Machine learning/logistic regression.ipynb Cell 30 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/monicavillarfuentes/codeacademy/Machine%20learning/logistic%20regression.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> model.score (x_test, y_test)
#
# NameError: name 'model' is not defined

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/monicavillarfuentes/codeacademy/Machine learning/logistic regression.ipynb Cell 31 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/monicavillarfuentes/codeacademy/Machine%20learning/logistic%20regression.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.metrics import confusion_matrix
# ----> <a href='vscode-notebook-cell:/Users/monicavillarfuentes/codeacademy/Machine%20learning/logistic%20regression.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> cm = confusion_matrix(y_test, y_predicted)
#       <a href='vscode-notebook-cell:/Users/monicavillarfuentes/codeacademy/Machine%20learning/logistic%20regression.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> cm
#
# NameError: name 'y_predicted' is not defined

# %%
print("Confusion matrix:")
print(confusion_matrix(y_test, pred_lr))
# Out:
# Confusion matrix:
# [[  0  33   6]
#  [  0 934 193]
#  [  0 144 160]]

# %%
#Visualisation of the CM

# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,4))
sns.heatmap(confusion_matrix, annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/monicavillarfuentes/codeacademy/Machine learning/logistic regression.ipynb Cell 33 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/Users/monicavillarfuentes/codeacademy/Machine%20learning/logistic%20regression.ipynb#X46sZmlsZQ%3D%3D?line=5'>6</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/Users/monicavillarfuentes/codeacademy/Machine%20learning/logistic%20regression.ipynb#X46sZmlsZQ%3D%3D?line=6'>7</a> plt.figure(figsize=(5,4))
# ----> <a href='vscode-notebook-cell:/Users/monicavillarfuentes/codeacademy/Machine%20learning/logistic%20regression.ipynb#X46sZmlsZQ%3D%3D?line=7'>8</a> sns.heatmap(confusion_matrix, annot=True)
#       <a href='vscode-notebook-cell:/Users/monicavillarfuentes/codeacademy/Machine%20learning/logistic%20regression.ipynb#X46sZmlsZQ%3D%3D?line=8'>9</a> plt.xlabel("Predicted")
#      <a href='vscode-notebook-cell:/Users/monicavillarfuentes/codeacademy/Machine%20learning/logistic%20regression.ipynb#X46sZmlsZQ%3D%3D?line=9'>10</a> plt.ylabel("Truth")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     362 """Plot rectangular data as a color-encoded matrix.
#     363
#     364 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     537     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     538 """
#     539 # Initialize the plotter object
# --> 540 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                       annot_kws, cbar, cbar_kws, xticklabels,
#     542                       yticklabels, mask)
#     544 # Add the pcolormesh kwargs here
#     545 kwargs["linewidths"] = linewidths
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:106, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     104 else:
#     105     plot_data = np.asarray(data)
# --> 106     data = pd.DataFrame(plot_data)
#     108 # Validate the mask and convet to DataFrame
#     109 mask = _matrix_mask(data, mask)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:694, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     684         mgr = dict_to_mgr(
#     685             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     686             # attribute "name"
#    (...)
#     691             typ=manager,
#     692         )
#     693     else:
# --> 694         mgr = ndarray_to_mgr(
#     695             data,
#     696             index,
#     697             columns,
#     698             dtype=dtype,
#     699             copy=copy,
#     700             typ=manager,
#     701         )
#     703 # For data is list-like, or Iterable (will consume into list)
#     704 elif is_list_like(data):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:331, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     326         values = values.reshape(-1, 1)
#     328 else:
#     329     # by definition an array here
#     330     # the dtypes will be coerced to a single dtype
# --> 331     values = _prep_ndarray(values, copy=copy_on_sanitize)
#     333 if dtype is not None and not is_dtype_equal(values.dtype, dtype):
#     334     shape = values.shape
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:591, in _prep_ndarray(values, copy)
#     589     values = values.reshape((values.shape[0], 1))
#     590 elif values.ndim != 2:
# --> 591     raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     593 return values
#
# ValueError: Must pass 2-d input. shape=()
